# %% [markdown]
# ---

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #### Displot

# %%
sns.distplot(tips['total_bill'], kde = False, bins=30)
## This is just a warning, it will be fixed in a future release of statsmodels.

# %% [markdown]
# #### Jointplot

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %% [markdown]
# ----

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %% [markdown]
# ----

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')
## This is just a warning, it will be fixed in a future release of statsmodels.
# Out:
# C:\Users\Dhananjay\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# -----

# %% [markdown]
# #### Pairplot

# %%
sns.pairplot(tips)

# %% [markdown]
# ----

# %%
pair_plot = sns.pairplot(tips,hue='sex')

# %%
pair_plot.savefig('tips_dataset.png',dpi=200)

# %% [markdown]
# ----

# %% [markdown]
# #### Rugplot

# %%
sns.rugplot(tips['total_bill'])

# %% [markdown]
# ---

# %% [markdown]
# #### Kde_plot

# %%
sns.kdeplot(tips['total_bill'])
# Out:
# C:\Users\Dhananjay\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# ------
